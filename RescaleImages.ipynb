# %%
import os
from PIL import Image

# %%
#Function to resize a folder of images to 256x256
#Credit for this function goes to: https://www.codespeedy.com/prepare-your-own-data-set-for-image-classification-python/
def resize_images(src_path, dst_path):
    # Here src_path is the location where images are saved.
    for filename in os.listdir(src_path):
        try:
            img=Image.open(src_path+filename)
            new_img = img.resize((256,256))
            if not os.path.exists(dst_path):
                os.makedirs(dst_path)
            new_img.save(dst_path+filename)
            print('Resized and saved {} successfully.'.format(filename))
        except:
            continue

# %%
src_path = '/Users/User/Desktop/MSc Project/English Cued Speech/SelectedShapes/'
dst_path = '/Users/User/Desktop/MSc Project/English Cued Speech/PhonemeImages/'
resize_images(src_path, dst_path)
# Out:
# Resized and saved 000027.png successfully.
# Resized and saved 000041.png successfully.
# Resized and saved 000049.png successfully.
# Resized and saved 000059.png successfully.
# Resized and saved 000064.png successfully.
# Resized and saved 000074.png successfully.
# Resized and saved 000080.png successfully.
# Resized and saved 000084.png successfully.
# Resized and saved 000089.png successfully.
# Resized and saved 000098.png successfully.
# Resized and saved 000103.png successfully.
# Resized and saved 000113.png successfully.
# Resized and saved 000119.png successfully.
# Resized and saved 000128.png successfully.
# Resized and saved 000135.png successfully.
# Resized and saved 000142.png successfully.
# Resized and saved 000161.png successfully.
# Resized and saved 000168.png successfully.
# Resized and saved 000177.png successfully.
# Resized and saved 000309.png successfully.
# Resized and saved 000320.png successfully.
# Resized and saved 000329.png successfully.
# ...

# %%
src_path = '/Users/User/Desktop/MSc Project/English Cued Speech/SelectedShapes-Consonants/'
dst_path = '/Users/User/Desktop/MSc Project/English Cued Speech/ConsonantImages/'
resize_images(src_path, dst_path)
# Out:
# Resized and saved 000059.png successfully.
# Resized and saved 000064.png successfully.
# Resized and saved 000074.png successfully.
# Resized and saved 000080.png successfully.
# Resized and saved 000084.png successfully.
# Resized and saved 000089.png successfully.
# Resized and saved 000098.png successfully.
# Resized and saved 000113.png successfully.
# Resized and saved 000128.png successfully.
# Resized and saved 000142.png successfully.
# Resized and saved 000168.png successfully.
# Resized and saved 000309.png successfully.
# Resized and saved 000320.png successfully.
# Resized and saved 000336.png successfully.
# Resized and saved 000344.png successfully.
# Resized and saved 000356.png successfully.
# Resized and saved 000366.png successfully.
# Resized and saved 000379.png successfully.
# Resized and saved 000387.png successfully.
# Resized and saved 000396.png successfully.
# Resized and saved 000405.png successfully.
# Resized and saved 000411.png successfully.
# ...

# %%
src_path = '/Users/User/Desktop/MSc Project/English Cued Speech/SelectedShapes-Vowels/'
dst_path = '/Users/User/Desktop/MSc Project/English Cued Speech/VowelImages/'
resize_images(src_path, dst_path)
# Out:
# Resized and saved 000027.png successfully.
# Resized and saved 000041.png successfully.
# Resized and saved 000049.png successfully.
# Resized and saved 000059.png successfully.
# Resized and saved 000064.png successfully.
# Resized and saved 000074.png successfully.
# Resized and saved 000080.png successfully.
# Resized and saved 000089.png successfully.
# Resized and saved 000098.png successfully.
# Resized and saved 000103.png successfully.
# Resized and saved 000113.png successfully.
# Resized and saved 000119.png successfully.
# Resized and saved 000135.png successfully.
# Resized and saved 000161.png successfully.
# Resized and saved 000168.png successfully.
# Resized and saved 000177.png successfully.
# Resized and saved 000309.png successfully.
# Resized and saved 000320.png successfully.
# Resized and saved 000329.png successfully.
# Resized and saved 000344.png successfully.
# Resized and saved 000356.png successfully.
# Resized and saved 000366.png successfully.
# ...

# %%
def resize_images_more(src_path, dst_path):
    # Here src_path is the location where images are saved.
    for filename in os.listdir(src_path):
        try:
            img=Image.open(src_path+filename)
            new_img = img.resize((64,64))
            if not os.path.exists(dst_path):
                os.makedirs(dst_path)
            new_img.save(dst_path+filename)
            print('Resized and saved {} successfully.'.format(filename))
        except:
            continue

# %%
src_path = '/Users/User/Desktop/MSc Project/English Cued Speech/SelectedShapes/'
dst_path = '/Users/User/Desktop/MSc Project/English Cued Speech/EvenSmallerImages/'
resize_images_more(src_path, dst_path)
# Out:
# Resized and saved 000027.png successfully.
# Resized and saved 000041.png successfully.
# Resized and saved 000049.png successfully.
# Resized and saved 000059.png successfully.
# Resized and saved 000064.png successfully.
# Resized and saved 000074.png successfully.
# Resized and saved 000080.png successfully.
# Resized and saved 000084.png successfully.
# Resized and saved 000089.png successfully.
# Resized and saved 000098.png successfully.
# Resized and saved 000103.png successfully.
# Resized and saved 000113.png successfully.
# Resized and saved 000119.png successfully.
# Resized and saved 000128.png successfully.
# Resized and saved 000135.png successfully.
# Resized and saved 000142.png successfully.
# Resized and saved 000161.png successfully.
# Resized and saved 000168.png successfully.
# Resized and saved 000177.png successfully.
# Resized and saved 000309.png successfully.
# Resized and saved 000320.png successfully.
# Resized and saved 000329.png successfully.
# ...
